# %%
from transformers import AutoTokenizer, AutoModel
import torch
from sklearn.metrics.pairwise import cosine_similarity

# %%
import pandas as pd

# %%
# !pip install nlpaug
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.9.1 requires ruamel-yaml, which is not installed.
# ...
#   Created wheel for gdown: filename=gdown-4.5.3-py3-none-any.whl size=14850 sha256=fa87a301712dbebcf268754a7d464044cf82a7aa247ce2e2a7a6be1dd43e59a4
#   Stored in directory: c:\users\ss-computer\appdata\local\pip\cache\wheels\2e\bf\38\838f7a301971b6fa2915069198ae7b48a21833d156ef170960
# Successfully built gdown
# ...
#   Attempting uninstall: requests
# ...

# %%
from nlpaug.util import Action
import transformers
from transformers import AutoTokenizer, AutoModel
import torch

# %%
data= pd.read_csv('trainFinance.csv')
data
# Out:
#        label                                             review
# 0          1  after a year of this we'll see how much profit...
# 1          1  the best way to get a feel for the market valu...
# 2          0                                 no need to find do
# 3          1  for sure, if you win money this year you can g...
# 4          0                               it's on the games no
# ...      ...                                                ...
# 19821      1  and it's been going up and down and up and dow...
# 19822      1  i would say, okay, i'm going to sell it at 70 ...
# 19823      0  can i ask you to when you enter the details ri...
# 19824      1  bowers is a member of the american bar associa...
# 19825      1  but if you think it's a bad company, you sell ...
#
# [19826 rows x 2 columns]

# %%
# aug_qa=[]
# new_label=[]
# ori_qa=[]

# for i in  range(2): 
#     for j in range(2):
#         aug_text = aug.augment(data['q_a'][i])
#         if aug_text != data['q_a'][i]:
#             aug_qa.append(aug_text)
#             new_label.append(data['label'][i])
#             ori_qa.append(data['q_a'][i])

# %%
aug_qa=[]
new_label=[]
for i in  range(19824): 
    aug_qa.append(data['review'][i])
    new_label.append(data['label'][i])
    for j in range(1):
        aug_text = aug.augment(data['review'][i])
        if aug_text != data['review'][i]:
            aug_qa.append(aug_text[0])
            new_label.append(data['label'][i])

# %%
print(len(aug_qa))
print(len(new_label))
my_dict = { 'review':aug_qa,'label':new_label}
df = pd.DataFrame(my_dict)
df.to_csv('augment_Bert_trainFinance.csv',index=False)
df.head(1000)
# Out:
# 39648
# 39648
#                                                 review  label
# 0    after a year of this we'll see how much profit...      1
# 1    in a year of this we'll see how much profit we...      1
# 2    the best way to get a feel for the market valu...      1
# 3    the best way to gain a feel for the market val...      1
# 4                                   no need to find do      0
# ..                                                 ...    ...
# 995  in particular that's good that i should have g...      0
# 996  and i'm going to talk with you in the monday w...      0
# 997  and i'm going to talk with her in the monday w...      0
# 998              write the financial conduct authority      0
# 999             write the national reporting authority      0
#
# [1000 rows x 2 columns]
